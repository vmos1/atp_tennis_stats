# %% [markdown]
# # This code reads a player name and looks at his record.

# %%
import numpy as np
import pandas as pd
import os
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(os.getcwd()+'/data/atp_players.csv')
df.columns=['ID','fname','lname','handed','DOB','Country']
print df.columns.values.tolist()
# Out:
# ['ID', 'fname', 'lname', 'handed', 'DOB', 'Country']

# %%
fn,ln='Rafael','Nadal'
d3=df.loc[(df['fname']== fn) & (df['lname']== ln)]
pid=d3.iloc[0][0]
d3
# Out:
#           ID   fname  lname handed       DOB Country
# 4740  104745  Rafael  Nadal      L  19860603     ESP

# %%
df2=pd.read_csv(os.getcwd()+'/data/rankings_data/atp_rankings_00s.csv')
df2.columns=['date','ranking','ID','Points']
print df2.shape
rnkg=df2.loc[(df2.iloc[:,2]== pid)]
history=rnkg.iloc[:,[0,1,3]]
history['date']=pd.to_datetime(history['date'].astype(str),format='%Y%m%d')

print history.reset_index()
# Out:
# /usr/lib64/python2.7/site-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
# -c:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (851680, 4)
#       index       date  ranking Points
# 0    129333 2001-09-24     1002      5
# 1    130988 2001-10-01      990      5
# 2    132640 2001-10-08      987      5
# 3    134299 2001-10-15      990      5
# 4    135948 2001-10-22      993      5
# 5    137607 2001-10-29     1009      5
# 6    139279 2001-11-05     1021      5
# 7    142282 2001-11-12      816     11
# 8    143939 2001-11-19      817     11
# 9    145499 2001-11-26      818     11
# 10   147163 2001-12-03      816     11
# ...

# %%
history.plot(x='date',y='ranking')

# %%
# pd.to_datetime(pd.Series(hs['date']).astype(str),format='%Y%m%d')
# hs['date']=pd.to_datetime(hs['date'].astype(str),format='%Y%m%d')

# %%
print df.columns
df2=df.loc[df['winner_name']=='Rafael' +' '+ 'Nadal']
print df2.shape
# Out:
# Index([u'ID', u'fname', u'lname', u'handed', u'DOB', u'Country'], dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-a8c318974a12> in <module>()
#       1 print df.columns
# ----> 2 df2=df.loc[df['winner_name']=='Rafael' +' '+ 'Nadal']
#       3 print df2.shape
#
# /usr/lib64/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /usr/lib64/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# ...

# %%
df=pd.read_csv('data/'+'/match_data/atp_matches_2005.csv')
print df.shape
# Out:
# (3257, 49)

# %%
df.loc[df['tourney_name']=='Paris Masters']
# Out:
#     tourney_id   tourney_name surface  draw_size tourney_level  tourney_date  \
# 895   2005-352  Paris Masters  Carpet         48             M      20051031
# 896   2005-352  Paris Masters  Carpet         48             M      20051031
# 897   2005-352  Paris Masters  Carpet         48             M      20051031
# 898   2005-352  Paris Masters  Carpet         48             M      20051031
# 899   2005-352  Paris Masters  Carpet         48             M      20051031
# 900   2005-352  Paris Masters  Carpet         48             M      20051031
# 901   2005-352  Paris Masters  Carpet         48             M      20051031
# 902   2005-352  Paris Masters  Carpet         48             M      20051031
# 903   2005-352  Paris Masters  Carpet         48             M      20051031
# 904   2005-352  Paris Masters  Carpet         48             M      20051031
# 905   2005-352  Paris Masters  Carpet         48             M      20051031
# ...

# %%
print df.iloc[np.arange(1,500),0]
# Out:
# 1       2005-891
# 2       2005-891
# 3       2005-891
# 4       2005-891
# 5       2005-891
# 6       2005-891
# 7       2005-891
# 8       2005-891
# 9       2005-891
# 10      2005-891
# 11      2005-891
# 12      2005-891
# 13      2005-891
# 14      2005-891
# 15      2005-891
# 16      2005-891
# 17      2005-891
# 18      2005-891
# 19      2005-891
# 20      2005-891
# 21      2005-891
# 22      2005-891
# 23      2005-891
# 24      2005-891
# 25      2005-891
# 26      2005-891
# 27      2005-891
# 28      2005-891
# 29      2005-891
# 30      2005-891
#          ...
# 470    2005-1536
# 471    2005-1536
# 472    2005-1536
# 473    2005-1536
# 474    2005-1536
# 475    2005-1536
# 476    2005-1536
# 477    2005-1536
# 478    2005-1536
# 479    2005-1536
# 480    2005-1536
# 481    2005-1536
# 482    2005-1536
# 483    2005-1536
# 484    2005-1536
# 485     2005-520
# 486     2005-520
# 487     2005-520
# 488     2005-520
# 489     2005-520
# 490     2005-520
# ...
